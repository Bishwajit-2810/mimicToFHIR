# %% [markdown]
# # CSV Inventory and Preview
#
# This notebook scans every `*.csv.gz` and `*.csv` file in `hosp` and `icu`, shows a compact inventory, and previews the first row of each dataset.
#
# The scan covers both compressed and plain CSV files so nothing is missed.

# %%
from pathlib import Path

from IPython.display import Markdown, display

import pandas as pd

base_dir = Path("/home/bk/code/Office/test/mimic-iv-clinical-database-demo-2.2")

for folder_name in ("hosp", "icu"):
    folder = base_dir / folder_name
    csv_paths = sorted({*folder.glob("*.csv.gz"), *folder.glob("*.csv")}, key=lambda path: path.name)

    display(Markdown(f"## {folder_name.upper()} ({len(csv_paths)} CSV files)"))

    summary_rows = []
    for csv_path in csv_paths:
        columns = pd.read_csv(csv_path, nrows=0).columns.tolist()
        preview = ', '.join(columns[:6]) + (' ...' if len(columns) > 6 else '')
        summary_rows.append({
            "file": csv_path.name,
            "columns": len(columns),
            "preview": preview,
        })

    display(pd.DataFrame(summary_rows))

    for csv_path in csv_paths:
        display(Markdown(f"### {csv_path.name}"))
        sample_df = pd.read_csv(csv_path, nrows=1)
        print(sample_df.head(5).T.to_string())
# Out:
# ## HOSP (22 CSV files)
#                          file  columns  \
# 0           admissions.csv.gz       16
# 1              d_hcpcs.csv.gz        4
# 2      d_icd_diagnoses.csv.gz        3
# 3     d_icd_procedures.csv.gz        3
# 4           d_labitems.csv.gz        4
# 5        diagnoses_icd.csv.gz        5
# 6             drgcodes.csv.gz        7
# 7                 emar.csv.gz       12
# 8          emar_detail.csv.gz       33
# 9          hcpcsevents.csv.gz        6
# 10           labevents.csv.gz       16
# 11  microbiologyevents.csv.gz       25
# 12                 omr.csv.gz        5
# 13            patients.csv.gz        6
# 14            pharmacy.csv.gz       27
# 15                 poe.csv.gz       12
# 16          poe_detail.csv.gz        5
# 17       prescriptions.csv.gz       21
# 18      procedures_icd.csv.gz        6
# 19            provider.csv.gz        1
# 20            services.csv.gz        5
# 21           transfers.csv.gz        7
#
#                                               preview
# 0   subject_id, hadm_id, admittime, dischtime, dea...
# 1   code, category, long_description, short_descri...
# 2                   icd_code, icd_version, long_title
# 3                   icd_code, icd_version, long_title
# 4                      itemid, label, fluid, category
# 5   subject_id, hadm_id, seq_num, icd_code, icd_ve...
# 6   subject_id, hadm_id, drg_type, drg_code, descr...
# 7   subject_id, hadm_id, emar_id, emar_seq, poe_id...
# 8   subject_id, emar_id, emar_seq, parent_field_or...
# 9   subject_id, hadm_id, chartdate, hcpcs_cd, seq_...
# 10  labevent_id, subject_id, hadm_id, specimen_id,...
# 11  microevent_id, subject_id, hadm_id, micro_spec...
# 12  subject_id, chartdate, seq_num, result_name, r...
# 13  subject_id, gender, anchor_age, anchor_year, a...
# 14  subject_id, hadm_id, pharmacy_id, poe_id, star...
# 15  poe_id, poe_seq, subject_id, hadm_id, ordertim...
# 16  poe_id, poe_seq, subject_id, field_name, field...
# 17  subject_id, hadm_id, pharmacy_id, poe_id, poe_...
# 18  subject_id, hadm_id, seq_num, chartdate, icd_c...
# 19                                        provider_id
# 20  subject_id, hadm_id, transfertime, prev_servic...
# 21  subject_id, hadm_id, transfer_id, eventtype, c...
# ### admissions.csv.gz
#                                              0
# subject_id                            10004235
# hadm_id                               24181354
# admittime                  2196-02-24 14:38:00
# dischtime                  2196-03-04 14:02:00
# deathtime                                  NaN
# admission_type                          URGENT
# admit_provider_id                       P03YMR
# admission_location      TRANSFER FROM HOSPITAL
# discharge_location    SKILLED NURSING FACILITY
# insurance                             Medicaid
# language                               ENGLISH
# marital_status                          SINGLE
# race                        BLACK/CAPE VERDEAN
# edregtime                  2196-02-24 12:15:00
# edouttime                  2196-02-24 17:07:00
# hospital_expire_flag                         0
# ### d_hcpcs.csv.gz
#                        0
# code               TD
# category             NaN
# long_description      Rn
# short_description     Rn
# ### d_icd_diagnoses.csv.gz
#                                                               0
# icd_code                                                     90
# icd_version                                                   9
# long_title   Infectious colitis, enteritis, and gastroenteritis
# ### d_icd_procedures.csv.gz
#                                            0
# icd_code                                  39
# icd_version                                9
# long_title   Other computer assisted surgery
# ### d_labitems.csv.gz
#                      0
# itemid           50808
# label     Free Calcium
# fluid            Blood
# category     Blood Gas
# ### diagnoses_icd.csv.gz
#                     0
# subject_id   10035185
# hadm_id      22580999
# seq_num             3
# icd_code         4139
# icd_version         9
# ### drgcodes.csv.gz
#                       0
# subject_id     10004235
# hadm_id        22187210
# drg_type           HCFA
# drg_code            864
# description       FEVER
# drg_severity        NaN
# drg_mortality       NaN
# ### emar.csv.gz
#                                      0
# subject_id                    10005909
# hadm_id                       20199380
# emar_id                    10005909-74
# emar_seq                            74
# poe_id                     10005909-97
# pharmacy_id                   96110427
# enter_provider_id                  NaN
# charttime          2144-10-31 05:56:00
# medication           Magnesium Sulfate
# event_txt                          NaN
# scheduletime       2144-10-31 05:56:00
# storetime          2144-10-31 05:56:00
# ### emar_detail.csv.gz
#                                                   0
# subject_id                                 10039708
# emar_id                               10039708-1750
# emar_seq                                       1750
# parent_field_ordinal                            1.1
# administration_type                             NaN
# pharmacy_id                                80400800
# barcode_type                                    NaN
# reason_for_no_barcode                           NaN
# complete_dose_not_given                         NaN
# dose_due                                        NaN
# dose_due_unit                                   NaN
# dose_given                                     0.25
# dose_given_unit                                  mg
# will_remainder_of_dose_be_given                 NaN
# product_amount_given                            NaN
# product_unit                                    NaN
# product_code                                    NaN
# product_description                             NaN
# product_description_other                       NaN
# prior_infusion_rate                             NaN
# infusion_rate                                   NaN
# infusion_rate_adjustment                        NaN
# infusion_rate_adjustment_amount                 NaN
# infusion_rate_unit                              NaN
# route                                           NaN
# infusion_complete                               NaN
# completion_interval                             NaN
# new_iv_bag_hung                                 NaN
# continued_infusion_in_other_location            NaN
# restart_interval                                NaN
# side                                            NaN
# site                                            NaN
# non_formulary_visual_verification               NaN
# ### hcpcsevents.csv.gz
#                                 0
# subject_id               10005348
# hadm_id                  29176490
# chartdate              2129-05-22
# hcpcs_cd                    93454
# seq_num                         1
# short_description  Cardiovascular
# ### labevents.csv.gz
#                                      0
# labevent_id                     172061
# subject_id                    10014354
# hadm_id                       29600294
# specimen_id                    1808066
# itemid                           51277
# order_provider_id                  NaN
# charttime          2148-08-16 00:00:00
# storetime          2148-08-16 01:30:00
# value                             15.4
# valuenum                          15.4
# valueuom                             %
# ref_range_lower                   10.5
# ref_range_upper                   15.5
# flag                               NaN
# priority                       ROUTINE
# comments                           NaN
# ### microbiologyevents.csv.gz
#                                                          0
# microevent_id                                           36
# subject_id                                        10000032
# hadm_id                                           25742920
# micro_specimen_id                                  7814634
# order_provider_id                                      NaN
# chartdate                              2180-08-06 00:00:00
# charttime                              2180-08-06 20:35:00
# spec_itemid                                          70070
# spec_type_desc                                        SWAB
# test_seq                                                 1
# storedate                              2180-08-08 00:00:00
# storetime                              2180-08-08 08:03:00
# test_itemid                                          90115
# test_name            R/O VANCOMYCIN RESISTANT ENTEROCOCCUS
# org_itemid                                             NaN
# org_name                                               NaN
# isolate_num                                            NaN
# quantity                                               NaN
# ab_itemid                                              NaN
# ab_name                                                NaN
# dilution_text                                          NaN
# dilution_comparison                                    NaN
# dilution_value                                         NaN
# interpretation                                         NaN
# comments                                No VRE isolated.
# ### omr.csv.gz
#                             0
# subject_id           10011398
# chartdate          2146-12-01
# seq_num                     1
# result_name   Height (Inches)
# result_value               63
# ### patients.csv.gz
#                              0
# subject_id            10014729
# gender                       F
# anchor_age                  21
# anchor_year               2125
# anchor_year_group  2011 - 2013
# dod                        NaN
# ### pharmacy.csv.gz
#                                                   0
# subject_id                                 10027602
# hadm_id                                    28166872
# pharmacy_id                                24340150
# poe_id                                          NaN
# starttime                       2201-10-30 12:00:00
# stoptime                                        NaN
# medication                                Midazolam
# proc_type                     Miscellaneous Charges
# status             Inactive (Due to a change order)
# entertime                       2201-10-30 12:32:11
# verifiedtime                                    NaN
# route                                           NaN
# frequency                                       NaN
# disp_sched                                      NaN
# infusion_type                                   NaN
# sliding_scale                                   NaN
# lockout_interval                                NaN
# basal_rate                                      NaN
# one_hr_max                                      NaN
# doses_per_24_hrs                                NaN
# duration                                        NaN
# duration_interval                               NaN
# expiration_value                                NaN
# expiration_unit                                 NaN
# expirationdate                                  NaN
# dispensation                                    NaN
# fill_quantity                                   NaN
# ### poe.csv.gz
#                                           0
# poe_id                         10002930-456
# poe_seq                                 456
# subject_id                         10002930
# hadm_id                            20282368
# ordertime               2201-03-23 19:14:33
# order_type                     General Care
# order_subtype                         Other
# transaction_type                        New
# discontinue_of_poe_id                   NaN
# discontinued_by_poe_id                  NaN
# order_provider_id                    P04TDP
# order_status                       Inactive
# ### poe_detail.csv.gz
#                        0
# poe_id       10011398-23
# poe_seq               23
# subject_id      10011398
# field_name      Admit to
# field_value      Surgery
# ### prescriptions.csv.gz
#                                      0
# subject_id                    10027602
# hadm_id                       28166872
# pharmacy_id                   27168639
# poe_id                             NaN
# poe_seq                            NaN
# order_provider_id                  NaN
# starttime          2201-10-30 12:00:00
# stoptime                           NaN
# drug_type                         MAIN
# drug                  Fentanyl Citrate
# formulary_drug_cd               FENT2I
# gsn                                NaN
# ndc                                NaN
# prod_strength                      NaN
# form_rx                            NaN
# dose_val_rx                        NaN
# dose_unit_rx                       NaN
# form_val_disp                      NaN
# form_unit_disp                     NaN
# doses_per_24_hrs                   NaN
# route                              NaN
# ### procedures_icd.csv.gz
#                       0
# subject_id     10011398
# hadm_id        27505812
# seq_num               3
# chartdate    2146-12-15
# icd_code           3961
# icd_version           9
# ### provider.csv.gz
#                   0
# provider_id  P003F3
# ### services.csv.gz
#                                 0
# subject_id               10001725
# hadm_id                  25563031
# transfertime  2110-04-11 15:09:36
# prev_service                  NaN
# curr_service                  GYN
# ### transfers.csv.gz
#                                0
# subject_id              10009049
# hadm_id                 22995465
# transfer_id             30030230
# eventtype              discharge
# careunit                     NaN
# intime       2174-05-31 14:21:47
# outtime                      NaN
# ## ICU (13 CSV files)
#                        file  columns  \
# 0          caregiver.csv.gz        1
# 1        chartevents.csv.gz       11
# 2            d_items.csv.gz        9
# 3     datetimeevents.csv.gz       10
# 4          discharge.csv.gz        8
# 5   discharge_detail.csv.gz        5
# 6           icustays.csv.gz        8
# 7   ingredientevents.csv.gz       17
# 8        inputevents.csv.gz       26
# 9       outputevents.csv.gz        9
# 10   procedureevents.csv.gz       22
# 11         radiology.csv.gz        8
# 12  radiology_detail.csv.gz        5
#
#                                               preview
# 0                                        caregiver_id
# 1   subject_id, hadm_id, stay_id, caregiver_id, ch...
# 2   itemid, label, abbreviation, linksto, category...
# 3   subject_id, hadm_id, stay_id, caregiver_id, ch...
# 4   note_id, subject_id, hadm_id, note_type, note_...
# 5   note_id, subject_id, field_name, field_value, ...
# 6   subject_id, hadm_id, stay_id, first_careunit, ...
# 7   subject_id, hadm_id, stay_id, caregiver_id, st...
# 8   subject_id, hadm_id, stay_id, caregiver_id, st...
# 9   subject_id, hadm_id, stay_id, caregiver_id, ch...
# 10  subject_id, hadm_id, stay_id, caregiver_id, st...
# 11  note_id, subject_id, hadm_id, note_type, note_...
# 12  note_id, subject_id, field_name, field_value, ...
# ### caregiver.csv.gz
#                 0
# caregiver_id  444
# ### chartevents.csv.gz
#                                 0
# subject_id               10005817
# hadm_id                  20626031
# stay_id                  32604416
# caregiver_id                 6770
# charttime     2132-12-16 00:00:00
# storetime     2132-12-15 23:45:00
# itemid                     225054
# value                         On
# valuenum                      NaN
# valueuom                      NaN
# warning                         0
# ### d_items.csv.gz
#                            0
# itemid                226228
# label                 Gender
# abbreviation          Gender
# linksto          chartevents
# category                 ADT
# unitname                 NaN
# param_type              Text
# lownormalvalue           NaN
# highnormalvalue          NaN
# ### datetimeevents.csv.gz
#                                 0
# subject_id               10002428
# hadm_id                  23473524
# stay_id                  35479615
# caregiver_id                29441
# charttime     2156-05-15 10:50:00
# storetime     2156-05-15 10:50:00
# itemid                     225343
# value         2156-05-11 00:00:00
# valueuom                     Date
# warning                         0
# ### discharge.csv.gz
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# note_id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# subject_id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# hadm_id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# note_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# note_seq                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# charttime                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# storetime                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# text         \nName:  ___                     Unit No:   ___\n \nAdmission Date:  ___              Discharge Date:   ___\n \nDate of Birth:  ___             Sex:   F\n \nService: MEDICINE\n \nAllergies: \nNo Known Allergies / Adverse Drug Reactions\n \nAttending: ___\n \nChief Complaint:\nWorsening ABD distension and pain \n \nMajor Surgical or Invasive Procedure:\nParacentesis\n\n \nHistory of Present Illness:\n___ HCV cirrhosis c/b ascites, hiv on ART, h/o IVDU, COPD, \nbioplar, PTSD, presented from OSH ED with worsening abd \ndistension over past week.  \nPt reports self-discontinuing lasix and spirnolactone ___ weeks \nago, because she feels like "they don't do anything" and that \nshe "doesn't want to put more chemicals in her." She does not \nfollow Na-restricted diets. In the past week, she notes that she \nhas been having worsening abd distension and discomfort. She \ndenies ___ edema, or SOB, or orthopnea. She denies f/c/n/v, d/c, \ndysuria. She had food poisoning a week ago from eating stale \ncake (n/v 20 min after food ingestion), which resolved the same \nday. She denies other recent illness or sick contacts. She notes \nthat she has been noticing gum bleeding while brushing her teeth \nin recent weeks. she denies easy bruising, melena, BRBPR, \nhemetesis, hemoptysis, or hematuria.  \nBecause of her abd pain, she went to OSH ED and was transferred \nto ___ for further care. Per ED report, pt has brief period of \nconfusion - she did not recall the ultrasound or bloodwork at \nosh. She denies recent drug use or alcohol use. She denies \nfeeling confused, but reports that she is forgetful at times.  \nIn the ED, initial vitals were 98.4 70 106/63 16 97%RA  \nLabs notable for ALT/AST/AP ___ ___: ___, \nTbili1.6, WBC 5K, platelet 77, INR 1.6  \n\n \nPast Medical History:\n1. HCV Cirrhosis  \n2. No history of abnormal Pap smears.  \n3. She had calcification in her breast, which was removed  \npreviously and per patient not, it was benign.  \n4. For HIV disease, she is being followed by Dr. ___ Dr.  \n___.  \n5. COPD  \n6. Past history of smoking.  \n7. She also had a skin lesion, which was biopsied and showed  \nskin cancer per patient report and is scheduled for a complete  \nremoval of the skin lesion in ___ of this year.  \n8. She also had another lesion in her forehead with purple  \ndiscoloration. It was biopsied to exclude the possibility of  \n___'s sarcoma, the results is pending.  \n9. A 15 mm hypoechoic lesion on her ultrasound on ___  \nand is being monitored by an MRI.  \n10. History of dysplasia of anus in ___.  \n11. Bipolar affective disorder, currently manic, mild, and PTSD. \n \n12. History of cocaine and heroin use.  \n\n \nSocial History:\n___\nFamily History:\nShe a total of five siblings, but she is not  \ntalking to most of them. She only has one brother that she is in \n \ntouch with and lives in ___. She is not aware of any  \nknown GI or liver disease in her family.  \nHer last alcohol consumption was one drink two months ago. No  \nregular alcohol consumption. Last drug use ___ years ago. She  \nquit smoking a couple of years ago.  \n\n \nPhysical Exam:\nVS: 98.1 107/61 78 18 97RA  \nGeneral: in NAD  \nHEENT: CTAB, anicteric sclera, OP clear  \nNeck: supple, no LAD  \nCV: RRR,S1S2, no m/r/g  \nLungs: CTAb, prolonged expiratory phase, no w/r/r  \nAbdomen: distended, mild diffuse tenderness, +flank dullness, \ncannot percuss liver/spleen edge ___ distension  \nGU: no foley  \nExt: wwp, no c/e/e, + clubbing  \nNeuro: AAO3, converse normally, able to recall 3 times after 5 \nminutes, CN II-XII intact  \n\nDischarge:\n\nPHYSICAL EXAMINATION:  \nVS: 98 105/70 95\nGeneral: in NAD  \nHEENT: anicteric sclera, OP clear  \nNeck: supple, no LAD  \nCV: RRR,S1S2, no m/r/g  \nLungs: CTAb, prolonged expiratory phase, no w/r/r  \nAbdomen: distended but improved, TTP in RUQ, \nGU: no foley  \nExt: wwp, no c/e/e, + clubbing  \nNeuro: AAO3,  CN II-XII intact  \n\n \nPertinent Results:\n___ 10:25PM   GLUCOSE-109*  ...
# ### discharge_detail.csv.gz
#                             0
# note_id        10000032-DS-21
# subject_id           10000032
# field_name             author
# field_value               ___
# field_ordinal               1
# ### icustays.csv.gz
#                                   0
# subject_id                 10018328
# hadm_id                    23786647
# stay_id                    31269608
# first_careunit       Neuro Stepdown
# last_careunit        Neuro Stepdown
# intime          2154-04-24 23:03:44
# outtime         2154-05-02 15:55:21
# los                        7.702512
# ### ingredientevents.csv.gz
#                                      0
# subject_id                    10005817
# hadm_id                       20626031
# stay_id                       32604416
# caregiver_id                      4793
# starttime          2132-12-17 05:00:00
# endtime            2132-12-17 06:00:00
# storetime          2132-12-17 06:01:00
# itemid                          227074
# amount                       49.999999
# amountuom                           ml
# rate                                50
# rateuom                        mL/hour
# orderid                        7330951
# linkorderid                    7330951
# statusdescription      FinishedRunning
# originalamount                       0
# originalrate                        50
# ### inputevents.csv.gz
#                                                       0
# subject_id                                     10005817
# hadm_id                                        20626031
# stay_id                                        32604416
# caregiver_id                                       4793
# starttime                           2132-12-16 19:50:00
# endtime                             2132-12-16 19:51:00
# storetime                           2132-12-16 19:50:00
# itemid                                           225798
# amount                                                1
# amountuom                                          dose
# rate                                                NaN
# rateuom                                             NaN
# orderid                                         3316866
# linkorderid                                     3316866
# ordercategoryname                   08-Antibiotics (IV)
# secondaryordercategoryname     02-Fluids (Crystalloids)
# ordercomponenttypedescription      Main order parameter
# ordercategorydescription                      Drug Push
# patientweight                                        91
# totalamount                                         500
# totalamountuom                                       ml
# isopenbag                                             0
# continueinnextdept                                    0
# statusdescription                       FinishedRunning
# originalamount                                        1
# originalrate                                          1
# ### outputevents.csv.gz
#                                 0
# subject_id               10002428
# hadm_id                  23473524
# stay_id                  35479615
# caregiver_id                29441
# charttime     2156-05-15 18:00:00
# storetime     2156-05-15 17:42:00
# itemid                     226583
# value                         600
# valueuom                       ml
# ### procedureevents.csv.gz
#                                             0
# subject_id                           10027445
# hadm_id                              26275841
# stay_id                              34499716
# caregiver_id                            10712
# starttime                 2142-07-31 01:54:00
# endtime                   2142-08-02 10:44:00
# storetime                 2142-08-02 10:44:00
# itemid                                 225792
# value                                    3410
# valueuom                                  min
# location                                  NaN
# locationcategory                          NaN
# orderid                                532221
# linkorderid                            532221
# ordercategoryname                 Ventilation
# ordercategorydescription    ContinuousProcess
# patientweight                             103
# isopenbag                                   1
# continueinnextdept                          0
# statusdescription             FinishedRunning
# ORIGINALAMOUNT                           3410
# ORIGINALRATE                                1
# ### radiology.csv.gz
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0
# note_id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            10000032-RR-14
# subject_id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               10000032
# hadm_id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  22595853
# note_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      RR
# note_seq                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       14
# charttime                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     2180-05-06 21:19:00
# storetime                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     2180-05-06 23:32:00
# text        EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATION:  ___ with new onset ascites  // eval for infection\n\nTECHNIQUE:  Chest PA and lateral\n\nCOMPARISON:  None.\n\nFINDINGS: \n\nThere is no focal consolidation, pleural effusion or pneumothorax.  Bilateral\nnodular opacities that most likely represent nipple shadows. The\ncardiomediastinal silhouette is normal.  Clips project over the left lung,\npotentially within the breast. The imaged upper abdomen is unremarkable.\nChronic deformity of the posterior left sixth and seventh ribs are noted.\n\nIMPRESSION: \n\nNo acute cardiopulmonary process.\n
# ### radiology_detail.csv.gz
#                             0
# note_id        10000032-RR-14
# subject_id           10000032
# field_name          exam_code
# field_value               C11
# field_ordinal               1
